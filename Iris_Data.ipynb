# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt

# %% [markdown]
# #### 1. Load data set using pandas function and print first 4 record.

# %%
MDF = pd.read_csv('iris.csv')
MDF.head(4)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa

# %% [markdown]
# #### 2. Print information of data set.

# %%
MDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### 3. Count the values of each class of species.

# %%
Variety = MDF['variety'].value_counts()
Variety
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %% [markdown]
# #### 4. Draw a line chart for sepal-length vs sepal-width.

# %%
x = MDF['sepal.length']
y = MDF['sepal.width']

mlt.plot(x,y)
mlt.title("sepal-length vs sepal-width")
# Out:
# Text(0.5, 1.0, 'sepal-length vs sepal-width')

# %% [markdown]
# #### 5. Print shape and size of the data frame.

# %%
print("Shape :" , MDF.shape)
print("size :" , MDF.size)
# Out:
# Shape : (150, 5)
# size : 750

# %% [markdown]
# #### 6. Print all the column header of the data frame.

# %%
MDF.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %% [markdown]
# #### 7. Filter the record from index no 80 to 100.

# %%
MDF.iloc[80:101]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 80            5.5          2.4           3.8          1.1  Versicolor
# 81            5.5          2.4           3.7          1.0  Versicolor
# 82            5.8          2.7           3.9          1.2  Versicolor
# 83            6.0          2.7           5.1          1.6  Versicolor
# 84            5.4          3.0           4.5          1.5  Versicolor
# 85            6.0          3.4           4.5          1.6  Versicolor
# 86            6.7          3.1           4.7          1.5  Versicolor
# 87            6.3          2.3           4.4          1.3  Versicolor
# 88            5.6          3.0           4.1          1.3  Versicolor
# 89            5.5          2.5           4.0          1.3  Versicolor
# 90            5.5          2.6           4.4          1.2  Versicolor
# 91            6.1          3.0           4.6          1.4  Versicolor
# ...

# %% [markdown]
# #### 8. Remove all the duplicate values from the data frame

# %%
MDF_No_Duplicates = MDF.drop_duplicates()

# %% [markdown]
# #### 9. Count the null values in the database and replace with median value

# %%
MDF.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64
