# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt

# %% [markdown]
# #### 1. Load data set using pandas function and print last 5 records.

# %%
MDF = pd.read_csv('flight.csv')
MDF.tail(5)
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 194            1917      -12.0      B6    1016  N304JB    JFK  BOS      36.0
# 195            2110       -5.0      B6     989  N663JB    JFK  FLL     152.0
# 196            1943       37.0      UA    1676  N37274    EWR  ORD     135.0
# 197            1949        8.0      EV    4581  N13566    EWR  CMH      95.0
# 198            1951       -6.0      B6    1111  N294JB    JFK  RDU      78.0
#
#      distance  hour  minute         time_hour
# ...

# %% [markdown]
# #### 2. Print the number of flight from one point to another.

# %%
MDF[['origin' , 'dest']].value_counts()
# Out:
# origin  dest
# JFK     LAX     6
# EWR     MCO     6
# LGA     ATL     6
# EWR     ORD     5
# LGA     ORD     5
#                ..
# EWR     SEA     1
#         SDF     1
#         SAT     1
#         SAN     1
# JFK     DEN     1
# Length: 106, dtype: int64

# %% [markdown]
# #### 3. Find the best airline in terms of departure.

# %% [markdown]
# #### 4. Create new column speed by calculating speed of airplane using distance and time taken to travel..

# %%
MDF['Speed'] = MDF['distance'] / MDF['hour']
MDF
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1      1455            1459         -4      1655
# 1    2013      1    1      1455            1500         -5      1753
# 2    2013      1    1      1456            1500         -4      1649
# 3    2013      1    1      1456            1455          1      1830
# 4    2013      1    1      1457            1500         -3      1758
# ..    ...    ...  ...       ...             ...        ...       ...
# 194  2013      1    1      1758            1800         -2      1905
# 195  2013      1    1      1758            1800         -2      2105
# 196  2013      1    1      1758            1749          9      2020
# 197  2013      1    1      1759            1759          0      1957
# 198  2013      1    1      1800            1800          0      1945
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %% [markdown]
# #### 5. Create a data frame containing total number of flights going to a particular destination.

# %% [markdown]
# #### 6. Find the size and shape of data set

# %%
print("Shape :" , MDF.shape)
print("size :" , MDF.size)
# Out:
# Shape : (199, 20)
# size : 3980

# %% [markdown]
# #### 7. Print all the column header of the dataframe.

# %%
MDF.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'Speed'],
#       dtype='object')

# %% [markdown]
# #### 8. Remove all the duplicate values from the data frame

# %%
mdf = MDF.drop_duplicates()

# %% [markdown]
# #### 9. Count the null values in the database and replace with mean value.

# %%
MDF.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         3
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          3
# distance          0
# hour              0
# minute            0
# time_hour         0
# Speed             0
# dtype: int64

# %%
MDF['arr_delay'].fillna(MDF['arr_delay'].mean , inplace=True)
MDF['air_time'].fillna(MDF['air_time'].mean , inplace=True)
MDF.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         0
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          0
# distance          0
# hour              0
# minute            0
# time_hour         0
# Speed             0
# dtype: int64
